# %% [markdown]
# <a href="https://colab.research.google.com/github/bokchisojeong/bokchi_open_lab/blob/main/getValAccFromReport.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
def getReportDetail(reportId, additionalAuth,authorization):
  url = "https://api.bokchi.com/api/graphql"
  
  body = """
  query ReportDetail($reportId: Long) {
    getReportDetail(reportId: $reportId) {
      editor {
        time
        blocks {
          id
          type
          data {
            text
            __typename
          }
          __typename
        }
        __typename
      }
      __typename
    }
  }
  """
  variables={"reportId": reportId}
  headers={
    "AdditionalAuth" : additionalAuth,
    "Authorization" : authorization  
  }
  response = requests.post(url=url, json={"query": body, "variables":variables},headers=headers)
  print("response status code: ", response.status_code)
  if response.status_code == 200:
      print("response : ", response.content)
      json_data=json.loads(response.content)
      for block in json_data["data"]["getReportDetail"]["editor"]["blocks"]:
        json_run_data=json.loads(block["data"]["text"])
        val_acc= []
        for run in json_run_data["runs"]:
          val_acc.append(run["summary"]["val_acc"])
        print(max(val_acc))


additionalAuth = "Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpYXQiOjE2ODMxMjI5MDgsImV4cCI6MTY4NTcxNDkwOCwic2hhcmUiOnsia2V5IjoiNGI4ZDI1ODY4MDA4NDVjNWRhY2ViNjMyZWVjMjljNGEiLCJ1c2VySWQiOjU0LCJ0eXBlIjoiUkVQVCIsImlkIjo0NTMsInJvbGUiOiJSRUFEIiwicGVyaW9kIjoiTU9OVEgifX0.h5eySascVcBNbZE7RKyooJGjUC_gbDWkptKywiZsih8"
authorization = "Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..q20Q0HNChI5vsLmGSe7PvlSHa0VECs5vGbSztj6mJEM"
getReportDetail(430, additionalAuth,authorization)
# Out:
# response status code:  200
# response :  b'{"data":{"getReportDetail":{"editor":{"time":"2023-05-03T07:08:33.185Z","blocks":[{"id":"0","type":"panelGrid","data":{"text":"{\\"expId\\":103,\\"expName\\":\\"cat_dog_cnn\\",\\"runs\\":[{\\"id\\":594,\\"experiment\\":{\\"id\\":103,\\"team\\":{\\"id\\":60,\\"teamName\\":\\"_TaeyoungPark\\",\\"teamType\\":\\"WORKS\\",\\"avatarUrl\\":\\"\\",\\"scope\\":\\"PRIVT\\",\\"createdAt\\":\\"2023-05-03T01:22:34.195Z\\",\\"updatedAt\\":\\"2023-05-03T01:22:34.195Z\\"},\\"name\\":\\"cat_dog_cnn\\",\\"description\\":\\"\\",\\"scope\\":\\"PRIVT\\",\\"createdAt\\":\\"2023-05-03T01:30:03.873Z\\",\\"updatedAt\\":\\"2023-05-03T06:24:51.010Z\\"},\\"name\\":\\"run_3\\",\\"displayName\\":\\"run_3\\",\\"state\\":\\"FINSH\\",\\"createdBy\\":{\\"userName\\":\\"TaeyoungPark\\",\\"language\\":\\"ENG\\",\\"country\\":\\"KOR\\",\\"role\\":\\"MEMBR\\"},\\"createAt\\":\\"2023-05-03T06:24:51.013Z\\",\\"updatedAt\\":\\"2023-05-03T06:41:16.443Z\\",\\"colorIndex\\":3,\\"lastStep\\":100,\\"info\\":{\\"os\\":\\"Linux\\",\\"python\\":\\"3.10.11\\",\\"gpu\\":\\"no gpu\\",\\"gpuCount\\":1,\\"cpuCount\\":2,\\"hostName\\":\\"6cc3c4f5e629\\"},\\"config\\":{\\"cliVer\\":\\"1.0.0\\",\\"pythonVer\\":\\"3.10.11\\",\\"batch_size\\":64,\\"architecture\\":\\"CNN\\",\\"learning_rate\\":0.0001,\\"epoch\\":100,\\"_custom\\":[{\\"key\\":\\"architecture\\",\\"value\\":\\"CNN\\"},{\\"key\\":\\"epoch\\",\\"value\\":100},{\\"key\\":\\"batch_size\\",\\"value\\":64},{\\"key\\":\\"hidden_layer\\",\\"value\\":512},{\\"key\\":\\"learning_rate\\",\\"value\\":0.0001},{\\"key\\":\\"cliVer\\",\\"value\\":\\"1.0.0\\"},{\\"key\\":\\"pythonVer\\",\\"value\\":\\"3.10.11\\"}]},\\"summary\\":{\\"_runtime\\":984.54553,\\"_step\\":100,\\"acc\\":1,\\"val_acc\\":1,\\"loss\\":0.0000012420248,\\"val_loss\\":8.951086e-7,\\"_custom\\":[{\\"key\\":\\"acc\\",\\"value\\":1},{\\"key\\":\\"loss\\",\\"value\\":0.0000012420248367561726},{\\"key\\":\\"val_acc\\",\\"value\\":1},{\\"key\\":\\"val_loss\\",\\"value\\":8.951085987973784e-7},{\\"key\\":\\"timestamp\\",\\"value\\":1683096065.853651},{\\"key\\":\\"system.cpu\\",\\"value\\":61.1},{\\"key\\":\\"system.disk\\",\\"value\\":23.62873077392578},{\\"key\\":\\"system.memory\\",\\"value\\":4.006446838378906},{\\"key\\":\\"system.proc.cpu.threads\\",\\"value\\":47},{\\"key\\":\\"system.proc.memory.rssMB\\",\\"value\\":4046.82421875},{\\"key\\":\\"system.proc.memory.percent\\",\\"value\\":31.164083364367457},{\\"key\\":\\"system.proc.memory.availableMB\\",\\"value\\":8567.27734375}]},\\"logged\\":{\\"logs\\":[{\\"_step\\":1,\\"acc\\":0.50051653,\\"val_acc\\":0.5052083,\\"loss\\":0.81085485,\\"val_loss\\":0.6898863,\\"_custom\\":[{\\"key\\":\\"acc\\",\\"value\\":0.5005165338516235},{\\"key\\":\\"loss\\",\\"value\\":0.8108548521995544},{\\"key\\":\\"val_acc\\",\\"value\\":0.5052083134651184},{\\"key\\":\\"val_loss\\",\\"value\\":0.6898862719535828},{\\"key\\":\\"timestamp\\",\\"value\\":1683095156.3482804},{\\"key\\":\\"system.cpu\\",\\"value\\":26.8},{\\"key\\":\\"system.disk\\",\\"value\\":23.62873077392578},{\\"key\\":\\"system.memory\\",\\"value\\":3.2925567626953125},{\\"key\\":\\"system.proc.cpu.threads\\",\\"value\\":47},{\\"key\\":\\"system.proc.memory.rssMB\\",\\"value\\":3404.0703125},{\\"key\\":\\"system.proc.memory.percent\\",\\"value\\":26.214316526376397},{\\"key\\":\\"system.proc.memory.availableMB\\",\\"value\\":9298.25}],\\"logData\\":[]},{\\"_step\\":2,\\"acc\\":0.5413223,\\"val_acc\\":0.5,\\"loss\\":0.6900906,\\"val_loss\\":0.68905544,\\"_custom\\":[{\\"key\\":\\"acc\\",\\"value\\":0.5413222908973694},{\\"key\\":\\"loss\\",\\"value\\":0.6900905966758728},{\\"key\\":\\"val_acc\\",\\"value\\":0.5},{\\"key\\":\\"val_loss\\",\\"value\\":0.6890554428100586},{\\"key\\":\\"timestamp\\",\\"value\\":1683095164.695643},{\\"key\\":\\"system.cpu\\",\\"value\\":74.1},{\\"key\\":\\"system.disk\\",\\"value\\":23.62873077392578},{\\"key\\":\\"system.memory\\",\\"value\\":3.4258384704589844},{\\"key\\":\\"system.proc.cpu.threads\\",\\"value\\":47},{\\"k ...
# 1
# 1
